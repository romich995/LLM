# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class TokenEmbeddings(nn.Module):
    def __init__(self, vocab_size: int, emb_size: int):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, emb_size)

    def forward(self, x: torch.Tensor):
        return self.embeddings(x)

# %%
emb = nn.Embedding(10, 5)

# %%
emb.weight
# Out:
# Parameter containing:
# tensor([[ 1.0417,  0.3734, -0.2845,  1.1437, -0.5285],
#         [-1.0246,  1.5675, -1.1470,  0.5448, -0.5771],
#         [ 1.6438,  0.4095,  1.4445,  0.6575, -0.6687],
#         [-0.0184,  1.5884,  0.9232,  0.2935,  0.7710],
#         [ 1.6182, -0.2352, -0.3802,  1.0957,  0.3755],
#         [-0.6078,  1.9853, -0.0308,  1.0325, -0.1747],
#         [-0.9909, -1.2750, -0.7506,  0.3749,  1.0448],
#         [-0.1280,  0.8441,  0.5540, -1.4530,  1.3447],
#         [ 0.1171, -0.0421, -0.2745, -0.2816,  1.5397],
#         [-0.1052,  1.2822,  0.6145, -2.4072,  1.4707]], requires_grad=True)

# %%
emb(torch.IntTensor([[1]]))
# Out:
# tensor([[[-1.0246,  1.5675, -1.1470,  0.5448, -0.5771]]],
#        grad_fn=<EmbeddingBackward0>)

# %%
TokenEmbeddings(10, 5)
# Out:
# TokenEmbeddings(
#   (embeddings): Embedding(10, 5)
# )
